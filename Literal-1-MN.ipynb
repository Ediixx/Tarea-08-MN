# %% [markdown]
# <div style="text-align: center;">
#
# ##### ESCUELA POLITÉCNICA NACIONAL
# ##### FACULTAD DE INGENIERÍA DE SISTEMAS
# ##### INGENIERÍA EN COMPUTACIÓN
# ##### MÉTODOS NUMÉRICOS
#
# </div>
#
# ##### NOMBRE: Edison Quizhpe
# ##### FECHA: 08/01/2025
#
# <div style="text-align: center;">
#
# #### TAREA N° 8
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a. Construya el polinomio por mínimos cuadrados de grado 1 y calcule el error.

# %%
x_i = (4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1)
y_i = (102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convertir los datos en arreglos de numpy
x = np.array(x_i)
y = np.array(y_i)

# Realizar el ajuste por mínimos cuadrados
coeficientes = np.polyfit(x, y, 1)  # Coeficientes del polinomio
polinomio = np.poly1d(coeficientes)  # Crear el polinomio a partir de los coeficientes

# Calcular los valores predichos de y
y_predicción = polinomio(x)

# Calcular el error relativo promedio
error_relativo_promedio = np.mean(np.abs((y - y_predicción) / y))

# Imprimir los resultados
print("Coeficientes del polinomio (a_1, a_0):", coeficientes)
print(f"El polinomio ajustado es: y = {coeficientes[0]:.4f}x  {coeficientes[1]:.4f}")
print(f"Error relativo promedio (ERP): {error_relativo_promedio:.4f}")

# Graficar los puntos y la línea ajustada
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='violet', label='Datos observados')  # Puntos originales
plt.plot(x, y_predicción, color='purple', label=f'Polinomio ajustado\ny = {coeficientes[0]:.4f}x + {coeficientes[1]:.4f}')  # Línea ajustada
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados con un polinomio de grado 1')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coeficientes del polinomio (a_1, a_0): [  71.61024372 -191.57241853]
# El polinomio ajustado es: y = 71.6102x  -191.5724
# Error relativo promedio (ERP): 0.0566

# %% [markdown]
# b. Construya el polinomio por mínimos cuadrados de grado 2 y calcule el error.

# %%
x_i = (4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1)
y_i = (102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convertir los datos en arreglos de numpy
x = np.array(x_i)
y = np.array(y_i)

# Realizar el ajuste por mínimos cuadrados
coeficientes = np.polyfit(x, y, 2)  # Coeficientes del polinomio
polinomio = np.poly1d(coeficientes)  # Crear el polinomio a partir de los coeficientes

# Calcular los valores predichos de y
y_predicción = polinomio(x)

# Calcular el error relativo promedio
error_relativo_promedio = np.mean(np.abs((y - y_predicción) / y))

# Imprimir los resultados
print("Coeficientes del polinomio (a_2, a_1, a_0):", coeficientes)
print(f"El polinomio ajustado es: y = {coeficientes[0]:.4f}x^2  {coeficientes[1]:.4f}x + {coeficientes[2]:.4f}")
print(f"Error relativo promedio (ERP): {error_relativo_promedio:.4f}")

# Graficar los puntos y la línea ajustada
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='orange', label='Datos observados')  # Puntos originales
plt.plot(x, y_predicción, color='green', label=f'Polinomio ajustado\ny = {coeficientes[0]:.4f}x^2 + {coeficientes[1]:.4f}x + {coeficientes[2]:.4f}')  # Línea ajustada
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados con polinomio de grado 2')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coeficientes del polinomio (a_2, a_1, a_0): [  8.21707232 -19.30860379  51.00078939]
# El polinomio ajustado es: y = 8.2171x^2  -19.3086x + 51.0008
# Error relativo promedio (ERP): 0.0333

# %% [markdown]
# c. Construya el polinomio por mínimos cuadrados de grado 3 y calcule el error.

# %%
x_i = (4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1)
y_i = (102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convertir los datos en arreglos de numpy
x = np.array(x_i)
y = np.array(y_i)

# Realizar el ajuste por mínimos cuadrados 
coeficientes = np.polyfit(x, y, 3)  # Coeficientes del polinomio
polinomio = np.poly1d(coeficientes)  # Crear el polinomio a partir de los coeficientes

# Calcular los valores predichos de y
y_predicción = polinomio(x)

# Calcular el error relativo promedio
error_relativo_promedio = np.mean(np.abs((y - y_predicción) / y))

# Imprimir los resultados
print("Coeficientes del polinomio (a_3, a_2, a_1, a_0):", coeficientes)
print(f"El polinomio ajustado es: y = {coeficientes[0]:.4f}x^3 + {coeficientes[1]:.4f}x^2  {coeficientes[2]:.4f}x + {coeficientes[3]:.4f}")
print(f"Error relativo promedio (ERP): {error_relativo_promedio:.4f}")

# Graficar los puntos y la línea ajustada
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label='Datos observados')  # Puntos originales
plt.plot(x, y_predicción, color='yellow', label=f'Polinomio ajustado\ny = {coeficientes[0]:.4f}x^3 + {coeficientes[1]:.4f}x^2 + {coeficientes[2]:.4f}x + {coeficientes[3]:.4f}')  # Línea ajustada
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados con polinomio de grado 3')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coeficientes del polinomio (a_3, a_2, a_1, a_0): [  -2.60683872   51.56095694 -254.87478338  469.16326528]
# El polinomio ajustado es: y = -2.6068x^3 + 51.5610x^2  -254.8748x + 469.1633
# Error relativo promedio (ERP): 0.0360

# %% [markdown]
# d. Construya el polinomio por mínimos cuadrados de la forma ![image.png](attachment:image.png) y calcule el error.

# %%
x_i = (4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1)
y_i = (102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convertir los datos en arreglos de numpy
x = np.array(x_i)
y = np.array(y_i)

# Transformar y tomando el logaritmo natural
log_y = np.log(y)

# Realizar el ajuste por mínimos cuadrados para un polinomio de grado 1 (recta) sobre ln(y)
coeficientes = np.polyfit(x, log_y, 1)  # Ajuste lineal en ln(y)
polinomio = np.poly1d(coeficientes)  # Crear el polinomio a partir de los coeficientes

# Calcular los valores predichos de ln(y)
log_y_predicción = polinomio(x)

# Convertir los valores predichos de ln(y) de vuelta a y usando la exponencial
y_predicción = np.exp(log_y_predicción)

# Calcular el error relativo promedio
error_relativo_promedio = np.mean(np.abs((y - y_predicción) / y))

# Extraer los coeficientes a y b
a = coeficientes[0]  # Coeficiente de x en ln(y) = A + Bx
b = np.exp(coeficientes[1])  # Intercepto, ln(b) = coeficiente[1], por lo que b = exp(coeficiente[1])

# Imprimir los resultados
print(f"Coeficientes del ajuste (a, b): a = {a:.4f}, b = {b:.4f}")
print(f"El polinomio ajustado es: y = {b:.4f}e^{a:.4f}x")
print(f"Error relativo promedio (ERP): {error_relativo_promedio:.4f}")

# Graficar los puntos y la curva ajustada
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Datos observados')  # Puntos originales
x_linea = np.linspace(min(x), max(x), 500)  # Más puntos para suavizar la línea ajustada
y_linea = b * np.exp(a * x_linea)  # Calcular los valores de y ajustados
plt.plot(x_linea, y_linea, color='turquoise', label=f'Curva ajustada\ny = {b:.4f}e^{a:.4f}x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados (Forma: y = be^ax)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coeficientes del ajuste (a, b): a = 0.3685, b = 24.7767
# El polinomio ajustado es: y = 24.7767e^0.3685x
# Error relativo promedio (ERP): 0.0490

# %% [markdown]
# e. Construya el polinomio por mínimos cuadrados de la forma ![image.png](attachment:image.png) y calcule el error.

# %%
x_i = (4.0,4.2,4.5,4.7,5.1,5.5,5.9,6.3,6.8,7.1)
y_i = (102.56,130.11,113.18,142.05,167.53,195.14,224.87,256.73,299.50,326.72)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convertir los datos en arreglos de numpy
x = np.array(x_i)
y = np.array(y_i)

# Transformar x e y tomando el logaritmo natural
log_x = np.log(x)
log_y = np.log(y)

# Realizar el ajuste por mínimos cuadrados para un polinomio de grado 1 (recta) sobre ln(x) y ln(y)
coeficientes = np.polyfit(log_x, log_y, 1)  # Ajuste lineal en ln(x) y ln(y)
polinomio = np.poly1d(coeficientes)  # Crear el polinomio a partir de los coeficientes

# Calcular los valores predichos de ln(y)
log_y_predicción = polinomio(log_x)

# Convertir los valores predichos de ln(y) de vuelta a y usando la exponencial
y_predicción = np.exp(log_y_predicción)

# Extraer los coeficientes a y b
a = coeficientes[0]  # Coeficiente de ln(x) en ln(y) = A + Bln(x)
b = np.exp(coeficientes[1])  # Intercepto, ln(b) = coeficiente[1], por lo que b = exp(coeficiente[1])

# Calcular el error relativo promedio
error_relativo_promedio = np.mean(np.abs((y - y_predicción) / y))

# Imprimir los resultados
print(f"Coeficientes del ajuste (a, b): a = {a:.4f}, b = {b:.4f}")
print(f"El polinomio ajustado es: y = {b:.4f}x^{a:.4f}")
print(f"Error relativo promedio (ERP): {error_relativo_promedio:.4f}")

# Graficar los puntos y la curva ajustada
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='cyan', label='Datos observados')  # Puntos originales
x_linea = np.linspace(min(x), max(x), 500)  # Más puntos para suavizar la línea ajustada
y_linea = b * x_linea**a  # Calcular los valores de y ajustados
plt.plot(x_linea, y_linea, color='red', label=f'Curva ajustada\ny = {b:.4f}x^{a:.4f}')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados (Forma: y = bx^a)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Coeficientes del ajuste (a, b): a = 1.9933, b = 6.5187
# El polinomio ajustado es: y = 6.5187x^1.9933
# Error relativo promedio (ERP): 0.0313
